# %%
from datetime import date
data = [(1,"balaji","jadhav","male","18000"),
         (2,"ramkishan","jadhav","male","20000"), 
         (3,"lavkush","pawar","male","25000"), 
         (4,"alok","pawar","male","30000"),
         (5,"gopal","rathod","male","40000"),
         (6,"mishti","more","female","40000"),
         (7,"aiti","aade","female","40000"),
         (3,"lavkush","pawar","male","25000"),
         (3,"lavkush","pawar","male","25000"),
         (7,"aiti","aade","female","40000"),
         (7,"aiti","aade","female","40000"),
         (4,"alok","pawar","male","30000"),]
schema = ["id","firstname","lastname","gender","salary"]
df=spark.createDataFrame(data=data,schema=schema)
df.show(truncate=False)
df.printSchema()

# %% [markdown]
# # distinct

# %%
df.distinct().count()

# %%
df.distinct().show()  # Remove Duplicates

# %%
df.select("lastname").distinct().show()

# %%
df.select("gender").distinct().show()

# %%
df.select("salary").distinct().show()
df.select("salary").distinct().count()

# %%
df.count()

# %% [markdown]
# # dropDuplicates

# %%
df.dropDuplicates().show()

# %%
df.dropDuplicates(["gender"]).show()

# %%
df.dropDuplicates(["gender","lastname"]).show()
