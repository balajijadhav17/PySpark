# %%
from datetime import date
data = [(1,"balaji","jadhav","male","18000","IT"),
         (2,"ramkishan","jadhav","male","20000","HR"), 
         (3,"lavkush","pawar","male","25000","Sales"), 
         (4,"alok","pawar","male","30000","Marketing"),
         (5,"gopal","rathod","male","40000","IT"),
         (6,"mishti","more","female","40000","HR"),
         (7,"aiti","aade","female","40000","Sales")]
schema = ["id","firstname","lastname","gender","salary","department"]
df=spark.createDataFrame(data=data,schema=schema)
display(df)

# %% [markdown]
# # sort

# %%
df.sort(df.department).show()

# %%
df.sort(df.salary.desc()).show()

# %%
df.sort("firstname").show()

# %%
df.sort(df.department,df.salary).show()

# %%
df.sort(df.department,df.salary.desc()).show()

# %%
df.sort(df.department.desc(),df.salary.desc()).show()

# %% [markdown]
# # orderBy

# %%
df.orderBy("lastname").show()

# %%
df.orderBy(df.lastname.desc()).show()

# %%
df.orderBy(df.id.desc()).show()

# %%
df.orderBy(df.id, df.salary.desc()).show()

# %%
df.orderBy(df.lastname, df.salary.desc()).show()

# %%
help(df.sort)
