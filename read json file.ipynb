# %% [markdown]
# # Read a JSON FILE

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Read JSON File").getOrCreate()

# %% [markdown]
# ### read json file method1

# %%
from pyspark.sql.types import *

schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True)
])

df = spark.read.schema(schema) \
    .json("/Volumes/pyspark/pyspark_schema/volume2/json_file/") 

df.show(truncate=False)

# %% [markdown]
# # Read a JSON FILE

# %%
df= spark.read.table("pyspark.pyspark_schema.`dataset_q&a`")
display(df)

# %%
df= spark.read.table("pyspark.pyspark_schema.`friends`")
display(df)

# %%
# %sql
drop table pyspark.pyspark_schema.`friends`;
