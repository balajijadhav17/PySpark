# %% [markdown]
# # Read a Parquet  File

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Read a Parquet  File").getOrCreate()

# %%
df=spark.read.parquet("/Volumes/pyspark/pyspark_schema/volume2/parquet_file/")
display(df)

# %%
df=spark.read.csv("/Volumes/pyspark/pyspark_schema/volume1/raw/",header=True,inferSchema=True)
df.show()
