# %% [markdown]
# # transform

# %%
from datetime import date
data = [(1,"balaji","jadhav",None,18000,None),
         (2,"ramkishan","jadhav","male",20000,"HR"), 
         (3,"lavkush","pawar","male",25000,"Sales"), 
         (4,"alok","pawar","male",None,"Marketing"),
         (5,"gopal","rathod","male",40000,"IT"),
         (6,"mishti","more",None,40000,"HR"),
         (7,"aiti",None,"female",40000,"Sales")]
schema = ["id","firstname","lastname","gender","salary","department"]
df=spark.createDataFrame(data=data,schema=schema)
df.show()
df.printSchema()

# %%
from pyspark.sql.functions import upper
def convertNametoUpper(df):
    return df.withColumn("firstname",upper(df.firstname))

def doublesalary(df):
    return df.withColumn("salary",df.salary*2)

# %%
df1=df.transform(convertNametoUpper)
df1.show()
df2=df1.transform(doublesalary)
df2.show()

# %%
df1=df.transform(convertNametoUpper)\
    .transform(doublesalary)
df1.show()
